# %% [markdown]
# # Shimi prototype
#
# Scratch space for experiments. Prefer committing small, reproducible snippets.

# %%
from pathlib import Path

import pandas as pd

root = Path("..").resolve()
df = pd.read_csv(root / "data" / "sample_lenders.csv")
df.head()
